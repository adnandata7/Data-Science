# %% [markdown]
# #### Q1. How can you create a Bokeh plot using Python code?

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers
output_file("file.html")
p= figure(title= "test_flower")
p.xaxis.axis_label = "sepal_length"
p.yaxis.axis_label = "sepal_width"
p.circle(flowers['sepal_length'], flowers['sepal_width'])
show(p)
# Out:
#   <div id="d648d193-c5a1-4993-ad32-66c4e99fe516" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# #### Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %% [markdown]
# Glyphs in Bokeh are the visual building blocks of Bokeh plots. They are basic shapes such as circles, squares, lines, etc., that are used to create complex visualizations.

# %%
output_file("glyphs_example.html")

p = figure(title="Glyphs Example", x_axis_label='X', y_axis_label='Y')

p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=10, color="navy", alpha=0.5)

p.square([1, 2, 3, 4, 5], [5, 4, 3, 2, 1], size=12, color="red", alpha=0.6)

show(p)
# Out:
#   <div id="c2485f3a-70c9-4bab-957a-31836fea55ee" data-root-id="p1048" style="display: contents;"></div>

# %% [markdown]
# #### Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
from bokeh.models import Legend

output_file("customized_plot.html")


p = figure(title="Customized Plot", x_axis_label='X Axis', y_axis_label='Y Axis')


r1 = p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=10, color="navy", alpha=0.5, legend_label="Circle")
r2 = p.square([1, 2, 3, 4, 5], [5, 4, 3, 2, 1], size=12, color="red", alpha=0.6, legend_label="Square")

# Customize title and axes
p.title.text_font_size = '14pt'
p.xaxis.axis_label_text_font_size = '12pt'
p.yaxis.axis_label_text_font_size = '12pt'

# Customize legend
p.legend.title = 'Shapes'
p.legend.title_text_font_style = 'bold'
p.legend.label_text_font_size = '10pt'
p.legend.location = 'top_left'


show(p)
# Out:
#   <div id="f157e706-3559-4cb8-83d5-404ae7c4d29b" data-root-id="p1100" style="display: contents;"></div>

# %% [markdown]
# #### Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in real time?

# %% [markdown]
# A Bokeh server allows you to build interactive web applications that can connect front-end visualizations with real-time data or updates. It enables dynamic updates to plots and interactions such as sliders or buttons that can trigger updates.
#
# Here's how you can utilize the Bokeh server to create interactive plots that can be updated in real time:
#
# 1. Create the initial Bokeh plot using the Bokeh library.
#
# 2. Write a Python script that defines the Bokeh server application.
#
# 3. Configure callbacks in the application to handle user interactions and updates.
#
# 4. Run the Bokeh server by executing the script.
#
# 5. Open a web browser and navigate to the provided URL.
#
# 6. Interact with the plot and observe real-time updates based on callbacks and user input.
#
# The Bokeh server provides the capability to construct dynamic, data-driven visualizations that respond to user actions and can be updated in real time.

# %% [markdown]
# #### Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [markdown]
# To embed a Bokeh plot into a web page or dashboard using Flask or Django, follow these steps:
#
# 1. Create the Bokeh plot using the Bokeh library.
#
# 2. Save the plot to an HTML file using Bokeh's save() function.
#
# 3. Integrate Flask or Django into your web application.
#
# 4. Define a route in your Flask or Django application to handle the plot's display.
#
# 5. Create an HTML template that will render the page with the embedded plot.
#
# 6. Load the HTML file containing the Bokeh plot in the route handler function.
#
# 7. Render the HTML template and include the Bokeh plot within it.
#
# 8. Start your Flask or Django application and access the URL to view the embedded Bokeh plot.
